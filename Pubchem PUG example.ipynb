# %%
from __future__ import print_function

# %% [markdown]
# Example how to use Pubchem PUG to bulk download list of CID and their smiles. The PUG POST request returns XML with an FTP link for the requested list in the requested format
#
# This should also be useful to download CSV data for AID's, theres an example at https://pubchemdocs.ncbi.nlm.nih.gov/power-user-gateway$_3-2-2 how to download two assays in CSV format.

# %%
#Example from here https://stackoverflow.com/questions/4476373/simple-url-get-post-function-in-python
import requests
url = 'https://pubchem.ncbi.nlm.nih.gov/pug/pug.cgi'
#payload = {'key1': 'value1', 'key2': 'value2'}

#Payload example generated with https://pubchem.ncbi.nlm.nih.gov/pc_fetch/pc_fetch.cgi
payload = """<?xml version="1.0"?>
<!DOCTYPE PCT-Data PUBLIC "-//NCBI//NCBI PCTools/EN" "http://pubchem.ncbi.nlm.nih.gov/pug/pug.dtd">
<PCT-Data>
  <PCT-Data_input>
    <PCT-InputData>
      <PCT-InputData_download>
        <PCT-Download>
          <PCT-Download_uids>
            <PCT-QueryUids>
              <PCT-QueryUids_ids>
                <PCT-ID-List>
                  <PCT-ID-List_db>pccompound</PCT-ID-List_db>
                  <PCT-ID-List_uids>
                    <PCT-ID-List_uids_E>241</PCT-ID-List_uids_E>
                    <PCT-ID-List_uids_E>727</PCT-ID-List_uids_E>
                  </PCT-ID-List_uids>
                </PCT-ID-List>
              </PCT-QueryUids_ids>
            </PCT-QueryUids>
          </PCT-Download_uids>
          <PCT-Download_format value="smiles"/>
          <PCT-Download_compression value="none"/>
          <PCT-Download_use-3d value="false"/>
        </PCT-Download>
      </PCT-InputData_download>
    </PCT-InputData>
  </PCT-Data_input>
</PCT-Data>"""
# GET
#r = requests.get(url)

# GET with params in URL
#r = requests.get(url, params=payload)

# POST with form-encoded data
r = requests.post(url, data=payload)

# POST with JSON 
#import json
#r = requests.post(url, data=json.dumps(payload))

# Response, status etc
print(r.text)
print(r.status_code)
# Out:
# <?xml version="1.0"?>
# <!DOCTYPE PCT-Data PUBLIC "-//NCBI//NCBI PCTools/EN" "http://pubchem.ncbi.nlm.nih.gov/pug/pug.dtd">
# <PCT-Data>
#   <PCT-Data_output>
#     <PCT-OutputData>
#       <PCT-OutputData_status>
#         <PCT-Status-Message>
#           <PCT-Status-Message_status>
#             <PCT-Status value="success"/>
#           </PCT-Status-Message_status>
#         </PCT-Status-Message>
#       </PCT-OutputData_status>
#       <PCT-OutputData_output>
#         <PCT-OutputData_output_download-url>
#           <PCT-Download-URL>
#             <PCT-Download-URL_url>ftp://ftp-private.ncbi.nlm.nih.gov/pubchem/.fetch/43/2756102283053941612.txt</PCT-Download-URL_url>
#           </PCT-Download-URL>
#         </PCT-OutputData_output_download-url>
#       </PCT-OutputData_output>
#     </PCT-OutputData>
#   </PCT-Data_output>
# </PCT-Data>
#
# 200

# %%
#Getting a long list of compounds

CIDs = [6603008, 6602571, 6602616, 644371, 6603132, 2850911, 6603374, 6603127, 644380, 2900108, 6602565, 644388, 644390, 644392, 644393, 644394, 644395, 644396, 644397, 5770444, 644399, 644401, 644402, 644403, 644404, 644405, 644406, 644407, 644408, 644409, 644410, 644411, 644412, 644413, 644415, 644417, 644418, 644419, 644420, 644421, 644422, 644423, 644424, 644425, 644426, 644427, 644428, 644429, 644430, 644434, 644435, 644436, 644437, 644438, 644439, 644440, 644442, 644443, 644444, 226199, 644445, 644446, 644447, 644448, 644449, 644450, 644451, 644452, 644453, 644454, 644455, 644456, 644457, 644458, 644460, 644461, 54690395, 644463, 644464, 644465, 644466, 644468, 644469, 644470, 644471, 644472, 644473, 644474, 644475, 644476, 644477, 644478, 644
, 645454, 645455, 645456, 645457, 645458, 645460, 645461, 6603461, 645470, 70863, 6603662, 645474, 6602582, 645478, 645481, 645482, 645483, 645486, 645487, 645488, 5711671, 645490, 645494, 645495, 645496, 645497, 645498, 645499, 645501, 645503, 645504, 645505, 5769020, 645507, 645508, 645512, 645513, 619283, 645514, 645515, 645516, 645517, 645518, 645520, 645521, 599871, 645523, 54689675, 645525, 645526, 645527, 304906, 645528, 645532, 645533, 5284840, 645536, 645537, 645538, 645539, 645540, 645541, 645542, 5347777, 5770442, 645548, 645549, 645551, 645552, 645553, 645554, 645556, 645557, 645558, 329167, 645559, 645560, 645562, 645563, 645564, 645565, 5347809, 645569, 645570, 645571, 645572, 5447101, 645574, 645575, 645576, 645577, 645578, 645580, 645582, 645583, 645584, 645585, 645586, 6602684, 6602617, 6602532, 645599, 6603179, 645603, 2931068, 645607, 6398895]


#Primitive XML generation
preamble = """<?xml version="1.0"?>
<!DOCTYPE PCT-Data PUBLIC "-//NCBI//NCBI PCTools/EN" "http://pubchem.ncbi.nlm.nih.gov/pug/pug.dtd">
<PCT-Data>
  <PCT-Data_input>
    <PCT-InputData>
      <PCT-InputData_download>
        <PCT-Download>
          <PCT-Download_uids>
            <PCT-QueryUids>
              <PCT-QueryUids_ids>
                <PCT-ID-List>
                  <PCT-ID-List_db>pccompound</PCT-ID-List_db>
                  <PCT-ID-List_uids>
                  """

postamble = """                  </PCT-ID-List_uids>
                </PCT-ID-List>
              </PCT-QueryUids_ids>
            </PCT-QueryUids>
          </PCT-Download_uids>
          <PCT-Download_format value="smiles"/>
          <PCT-Download_compression value="none"/>
          <PCT-Download_use-3d value="false"/>
        </PCT-Download>
      </PCT-InputData_download>
    </PCT-InputData>
  </PCT-Data_input>
</PCT-Data>
"""

compounds = []

for cid in CIDs:
    compounds.append("<PCT-ID-List_uids_E>%i</PCT-ID-List_uids_E>"%cid)
    
payload = preamble + "\n".join(compounds) + postamble

print(payload)
# Out:
# <?xml version="1.0"?>
# <!DOCTYPE PCT-Data PUBLIC "-//NCBI//NCBI PCTools/EN" "http://pubchem.ncbi.nlm.nih.gov/pug/pug.dtd">
# <PCT-Data>
#   <PCT-Data_input>
#     <PCT-InputData>
#       <PCT-InputData_download>
#         <PCT-Download>
#           <PCT-Download_uids>
#             <PCT-QueryUids>
#               <PCT-QueryUids_ids>
#                 <PCT-ID-List>
#                   <PCT-ID-List_db>pccompound</PCT-ID-List_db>
#                   <PCT-ID-List_uids>
#                   <PCT-ID-List_uids_E>6603008</PCT-ID-List_uids_E>
# <PCT-ID-List_uids_E>6602571</PCT-ID-List_uids_E>
# <PCT-ID-List_uids_E>6602616</PCT-ID-List_uids_E>
# <PCT-ID-List_uids_E>644371</PCT-ID-List_uids_E>
# <PCT-ID-List_uids_E>6603132</PCT-ID-List_uids_E>
# <PCT-ID-List_uids_E>2850911</PCT-ID-List_uids_E>
# <PCT-ID-List_uids_E>6603374</PCT-ID-List_uids_E>
# <PCT-ID-List_uids_E>6603127</PCT-ID-List_uids_E>
# <PCT-ID-List_uids_E>644380</PCT-ID-List_uids_E>
# <PCT-ID-List_uids_E>2900108</PCT-ID-List_uids_E>
# ...

# %%
import pandas as pd
import re
import time

time0 = time.time()

r = requests.post(url, data=payload)

regexp = re.compile("<PCT-Download-URL_url>(.*)<\/PCT-Download-URL_url>") #This may fail if CSV is not ready, then requerying may be necessary
ftpurl = regexp.findall(r.text)[0]

data = pd.read_csv(ftpurl, sep="\t", names=["CID","SMILES"])

time1 = time.time()
print("Query and download %0.0F ms pr. compound"%(time1-time0))
# Out:
# Query and download 16 ms pr. compound

# %%
data
# Out:
#          CID                                             SMILES
# 0    6603008            CCOCCCNCC(=O)NC1=CC=C(C=C1)OC(F)(F)F.Cl
# 1    6602571          COCCN1C(=NN=N1)CN2CCC(CC2)CC3=CC=CC=C3.Cl
# 2    6602616  COCCN1C(=NN=N1)CN2CCC(CC2)(C3=CC(=CC=C3)C(F)(F...
# 3     644371  C1CCCN(CC1)CC(=O)NCCC2=CC=C(C=C2)F.C(=O)(C(=O)O)O
# 4    6603132      COC1=CC=C(C=C1)C(=O)C(C2=CC=CC=C2)N3CCOCC3.Cl
# 5    2850911                   CCOC(=O)CCNCC1COC2=CC=CC=C2O1.Cl
# 6    6603374       CCOC(=O)N1CCN(CC1)CCC(=O)NC2=CC(=CC=C2)Br.Cl
# 7    6603127           CC(=O)OC1(CCN(C2C1CCCC2)C)C3=CC=CC=C3.Cl
# 8     644380         CCCCOCC(CN1CCN(CC1)C(=O)C)O.C(=O)(C(=O)O)O
# 9    2900108          CC(C(=O)NCC1(CCCC1)C2=CC=CC=C2)N3CCCC3.Cl
# 10   6602565      C1CCN(CC1)C2=NC3=CC=CC=C3C(=N2)NCC4=CC=CO4.Cl
# 11    644388  CN1C(=CN=C1NCC2=C(C=CC(=C2)Cl)O)C3=CC(=CC=C3)O...
# 12    644390           CCOC(=O)N1CCC(CC1)NCCNC(=O)C2=CC=CC=C2Cl
# 13    644392  CN1C(=O)CC(SC1=NC2=CC(=CC=C2)OC)C(=O)NC3=CC=CC...
# ...

# %%
import pandas as pd
pd.read_csv("ftp://ftp-private.ncbi.nlm.nih.gov/pubchem/.fetch/9/2471099105806511333.txt", sep='\t', names=["CID", "SMILES"])
# Out:
#          CID                                             SMILES
# 0    6603008            CCOCCCNCC(=O)NC1=CC=C(C=C1)OC(F)(F)F.Cl
# 1    6602571          COCCN1C(=NN=N1)CN2CCC(CC2)CC3=CC=CC=C3.Cl
# 2    6602616  COCCN1C(=NN=N1)CN2CCC(CC2)(C3=CC(=CC=C3)C(F)(F...
# 3     644371  C1CCCN(CC1)CC(=O)NCCC2=CC=C(C=C2)F.C(=O)(C(=O)O)O
# 4    6603132      COC1=CC=C(C=C1)C(=O)C(C2=CC=CC=C2)N3CCOCC3.Cl
# 5    2850911                   CCOC(=O)CCNCC1COC2=CC=CC=C2O1.Cl
# 6    6603374       CCOC(=O)N1CCN(CC1)CCC(=O)NC2=CC(=CC=C2)Br.Cl
# 7    6603127           CC(=O)OC1(CCN(C2C1CCCC2)C)C3=CC=CC=C3.Cl
# 8     644380         CCCCOCC(CN1CCN(CC1)C(=O)C)O.C(=O)(C(=O)O)O
# 9    2900108          CC(C(=O)NCC1(CCCC1)C2=CC=CC=C2)N3CCCC3.Cl
# 10   6602565      C1CCN(CC1)C2=NC3=CC=CC=C3C(=N2)NCC4=CC=CO4.Cl
# 11    644388  CN1C(=CN=C1NCC2=C(C=CC(=C2)Cl)O)C3=CC(=CC=C3)O...
# 12    644390           CCOC(=O)N1CCC(CC1)NCCNC(=O)C2=CC=CC=C2Cl
# 13    644392  CN1C(=O)CC(SC1=NC2=CC(=CC=C2)OC)C(=O)NC3=CC=CC...
# ...

# %%
help(pd.read_csv)
# Out:
# Help on function read_csv in module pandas.io.parsers:
#
# ...

# %%
AID = 1224905

payload = """<PCT-Data>
  <PCT-Data_input>
    <PCT-InputData>
      <PCT-InputData_query>
        <PCT-Query>
          <PCT-Query_type>
            <PCT-QueryType>
              <PCT-QueryType_bas>
                <PCT-QueryAssayData>
                  <PCT-QueryAssayData_output value="csv">4</PCT-QueryAssayData_output>
                  <PCT-QueryAssayData_aids>
                    <PCT-QueryUids>
                      <PCT-QueryUids_ids>
                        <PCT-ID-List>
                          <PCT-ID-List_db>pcassay</PCT-ID-List_db>
                          <PCT-ID-List_uids>
                            <PCT-ID-List_uids_E>%s</PCT-ID-List_uids_E>
                          </PCT-ID-List_uids>
                        </PCT-ID-List>
                      </PCT-QueryUids_ids>
                    </PCT-QueryUids>
                  </PCT-QueryAssayData_aids>
                  <PCT-QueryAssayData_dataset value="complete">0</PCT-QueryAssayData_dataset>
                  <PCT-QueryAssayData_focus>
                    <PCT-Assay-FocusOption>
                      <PCT-Assay-FocusOption_group-results-by value="substance">4</PCT-Assay-FocusOption_group-results-by>
                    </PCT-Assay-FocusOption>
                  </PCT-QueryAssayData_focus>
                </PCT-QueryAssayData>
              </PCT-QueryType_bas>
            </PCT-QueryType>
          </PCT-Query_type>
        </PCT-Query>
      </PCT-InputData_query>
    </PCT-InputData>
  </PCT-Data_input>
</PCT-Data>"""%AID

r = requests.post(url, data=payload)

# POST with JSON 
#import json
#r = requests.post(url, data=json.dumps(payload))

# Response, status etc
print(r.text)
print(r.status_code)
# Out:
# <?xml version="1.0"?>
# <!DOCTYPE PCT-Data PUBLIC "-//NCBI//NCBI PCTools/EN" "http://pubchem.ncbi.nlm.nih.gov/pug/pug.dtd">
# <PCT-Data>
#   <PCT-Data_output>
#     <PCT-OutputData>
#       <PCT-OutputData_status>
#         <PCT-Status-Message>
#           <PCT-Status-Message_status>
#             <PCT-Status value="running"/>
#           </PCT-Status-Message_status>
#         </PCT-Status-Message>
#       </PCT-OutputData_status>
#       <PCT-OutputData_output>
#         <PCT-OutputData_output_waiting>
#           <PCT-Waiting>
#             <PCT-Waiting_reqid>4235261345408015414</PCT-Waiting_reqid>
#           </PCT-Waiting>
#         </PCT-OutputData_output_waiting>
#       </PCT-OutputData_output>
#     </PCT-OutputData>
#   </PCT-Data_output>
# </PCT-Data>
#
# 200

# %%
#Polling request
payload = """<PCT-Data>
  <PCT-Data_input>
    <PCT-InputData>
      <PCT-InputData_request>
        <PCT-Request>
          <PCT-Request_reqid>4235261345408015414</PCT-Request_reqid>
          <PCT-Request_type value="status"/>
        </PCT-Request>
      </PCT-InputData_request>
    </PCT-InputData>
  </PCT-Data_input>
</PCT-Data>"""

r = requests.post(url, data=payload)

print(r.text)
print(r.status_code)
# Out:
# <?xml version="1.0"?>
# <!DOCTYPE PCT-Data PUBLIC "-//NCBI//NCBI PCTools/EN" "http://pubchem.ncbi.nlm.nih.gov/pug/pug.dtd">
# <PCT-Data>
#   <PCT-Data_output>
#     <PCT-OutputData>
#       <PCT-OutputData_status>
#         <PCT-Status-Message>
#           <PCT-Status-Message_status>
#             <PCT-Status value="success"/>
#           </PCT-Status-Message_status>
#         </PCT-Status-Message>
#       </PCT-OutputData_status>
#       <PCT-OutputData_output>
#         <PCT-OutputData_output_download-url>
#           <PCT-Download-URL>
#             <PCT-Download-URL_url>ftp://ftp-private.ncbi.nlm.nih.gov/pubchem/.fetch/b884235261345408015414.csv.gz</PCT-Download-URL_url>
#           </PCT-Download-URL>
#         </PCT-OutputData_output_download-url>
#       </PCT-OutputData_output>
#     </PCT-OutputData>
#   </PCT-Data_output>
# </PCT-Data>
#
# 200

# %%
#Cancel request
payload = """<PCT-Data>
  <PCT-Data_input>
    <PCT-InputData>
      <PCT-InputData_request>
        <PCT-Request>
          <PCT-Request_reqid>4235261345408015414</PCT-Request_reqid>
          <PCT-Request_type value="cancel"/>
        </PCT-Request>
      </PCT-InputData_request>
    </PCT-InputData>
  </PCT-Data_input>
</PCT-Data>"""
